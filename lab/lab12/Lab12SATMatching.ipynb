# %% [markdown]
# # Problem SAT z zastosowaniem w kombinatoryce: Skojarzenie w grafach
#
# ### Metody Formalne i Weryfikacja Protokołów Kryptograficznych. MCB, 2026L. HG.
#
# Celem dzisiejszych laboratoriów jest zapoznanie się z biblioteką `networkx` oraz omówienie generowania formuł logicznych dla zadanego problemu na przykładzie opracowanej formuły do stwierdzania, czy istnieje skojarzenie o dokładnie 4 krawędziach w grafie (model z poprzednich zajęć).

# %% [markdown]
# ## IMIĘ I NAZWISKO
#
# Należy wprowadzić swoje imię i nazwisko.

# %% [markdown]
# ## Importy

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Zadanie 1
# ### Zapoznanie z biblioteką networkx
#
# Zapoznaj się z dokumentacją biblioteki `networkx`. Następnie, zdefiniuj graf $G = (V, E)$, gdzie $V = [10]$ oraz $E = \{1-3, 1-6, 1-10, 2-5, 2-6, 3-7, 4-10, 5-7, 5-8, 7-9, 7-10, 8-10, 9-10\}$.

# %%
# TODO
# G = ...

# %% [markdown]
# Zapoznaj się ze sposobem opisu wierzchołków i krawędzi grafu G.

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
print(list(G.edges()))

# %% [markdown]
# ## Zadanie 2
# ### Formuła szukająca skojarzenia w grafie.
#
# Przypomnij sobie formułę logiczną z poprzednich zajęć opisującą problem znajdowania w grafie $G$ skojarzenia o dokładnie 4 krawędziach. Przypomnijmy, że mieliśmy w tym modelu $m$ zmiennych boolowskich, gdzie $m$ to liczba krawędzi grafu $G$. Napisz funkcję, która:
# - każdej krawędzi przypisze numer zmiennej.
# - zwróci słownik, którego kluczami będą krawędzie, a wartościami numer zmiennej.
#
# Przykładowy output:

# %%
{ (0,1) : 1,
  (1,2) : 2,
  (2,3) : 3}

# %%
def edge_variables(graph):
    # TODO
    pass

# %% [markdown]
# Napisz funkcję, która generuje odpowiednie klauzule zgodnie z formułą do znajdowania skojarzenia o dokładnie 4 krawędziach w grafie. Każda klauzula ma być przechowywana jako lista zmiennych lub jej zaprzeczeń w nich występujących. Wynikiem funkcji ma być lista klauzul.

# %%
example_clause = [1, -3] # Przyklad klauzuli (x_1 \lor (\neg x_3))
example_output = [[1, -3], [2, 1]] # Przyklad wyjscia z funkcji

# %%
def generate_formula(graph):
    # TODO
    pass

# %% [markdown]
# ## Zadanie 3
#
# ### Naiwne szukanie rozwiązania.
#
# Jak wiemy z wykładu, istnieją algorytmy wykorzystywane do analizy formuł logicznych i ich spełnialności, jak np. algorytm CDCL. W tym zadaniu, chcemy jednak analizować istnienie odpowiedniego wartościowania metodą brute-force.
#
# Napisz funkcję, która:
# - przyjmuje na wejściu listę klauzul
# - naiwnie sprawdza każde kolejne wartościowanie zmiennych
# - jeśli wartościowanie zapewnia spełnialność formuły, zwróć to wartościowanie
# - jeśli żadne wartościowanie go nie zapewniło, zwróć None

# %%
def brute_force_sat_solver(list_of_clauses):
    # TODO
    pass

# %% [markdown]
# ## Zadanie 4
#
# ### Odczytanie rozwiązania i jego wizualizacja.
#
# Dla zdefiniowanego wcześniej grafu $G$, przy pomocy rozwiązanych zadań zweryfikuj, czy istnieje skojarzenie o dokładnie 4 krawędziach w tym grafie. Konkretnie, napisz funkcję (i następnie ją wykorzystaj), która:
# - ma odczytać, które zmienne mają wartość True,
# - zwrócić odpowiadające im krawędzie.

# %%
def extract_matching(solution, variables):
    # TODO
    pass

# %%
matching = extract_matching(solution, variables) # matching ma zawierać krawędzie znalezionego skojarzenia
print(matching)

# %% [markdown]
# Zapoznaj się z możliwościami rysowania grafów przy pomocy bibliotek `networkx` oraz `matplotlib`. Następnie, narysuj graf $G$, przy czym krawędzie mają być w kolorze szarym, a te, które są w znalezionym skojarzeniu, pogrubione i na czerwono.

# %%
def draw_matching(graph, matching):
    # TODO
    pass

# %%
draw_matching(G, matching) # Test wizualizacji

# %% [markdown]
# Dziękuję za dzisiejsze lab :)
